# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = list(range(100))
x_np = np.array(x)

# %%
b = 3

# %%
noise = np.random.normal(10,5,size = 100)

# %%
y = (x_np * b )+noise

# %%
import seaborn as sns
sns.scatterplot(x = x_np,y = y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable");

# %%
alpha = 0.0001  
iterations = 1000  
m = len(x)

# Gradient Descent
for i in range(iterations):
    y_pred = beta_0 + beta_1 * x
    
    gradient_beta_0 = (-2/m) * np.sum(y - y_pred)
    gradient_beta_1 = (-2/m) * np.dot(x, (y - y_pred))
    
    # Update betas
    beta_0 -= alpha * gradient_beta_0
    beta_1 -= alpha * gradient_beta_1

    # Optionally print the parameters at regular intervals
    if i % 100 == 0:
        print(f"Iteration {i}: beta_0 = {beta_0}, beta_1 = {beta_1}")

# Output the final betas
print(f"Final Estimated coefficients: beta_0 = {beta_0}, beta_1 = {beta_1}")

# Plotting the results
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', label='Data points')
plt.plot(x, beta_0 + beta_1 * x, color='red', label=f'Best-fit line: y = {beta_0:.2f} + {beta_1:.2f}x')
plt.title("Linear Regression via Gradient Descent")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
# Out:
# Iteration 0: beta_0 = 0.019779712632670574, beta_1 = 2.3127642591654087
# Iteration 100: beta_0 = 0.028899549485787768, beta_1 = 2.998595964952392
# Iteration 200: beta_0 = 0.027685867518564437, beta_1 = 2.9986142630793347
# Iteration 300: beta_0 = 0.02647832860208184, beta_1 = 2.998632468590316
# Iteration 400: beta_0 = 0.025276901643291435, beta_1 = 2.9986505819541116
# Iteration 500: beta_0 = 0.024081555706522026, beta_1 = 2.9986686036371246
# Iteration 600: beta_0 = 0.02289226001268336, beta_1 = 2.998686534103397
# Iteration 700: beta_0 = 0.021708983938473474, beta_1 = 2.998704373814622
# Iteration 800: beta_0 = 0.020531697015590312, beta_1 = 2.9987221232301566
# Iteration 900: beta_0 = 0.01936036892994705, beta_1 = 2.998739782807032
# Final Estimated coefficients: beta_0 = 0.01820659426669057, beta_1 = 2.998757177739001
